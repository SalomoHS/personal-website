# %%
import smtplib
from email.mime.text import MIMEText

subject = "Email Subject"
body = "This is the body of the text message"
sender = "omo.workstation@gmail.com"
recipients = ["isalomohendriyan@gmail.com",]
password = "7762323ok"


def send_email(subject, body, sender, recipients, password):
    msg = MIMEText(body)
    msg['Subject'] = subject
    msg['From'] = sender
    msg['To'] = ', '.join(recipients)
    with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
       smtp_server.login(sender, password)
       smtp_server.sendmail(sender, recipients, msg.as_string())
    print("Message sent!")


send_email(subject, body, sender, recipients, password)
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[3], line 22
#      18        smtp_server.sendmail(sender, recipients, msg.as_string())
#      19     print("Message sent!")
# ---> 22 send_email(subject, body, sender, recipients, password)
#
# Cell In[3], line 17, in send_email(subject, body, sender, recipients, password)
#      15 msg['To'] = ', '.join(recipients)
#      16 with smtplib.SMTP_SSL('smtp.gmail.com', 465) as smtp_server:
# ---> 17    smtp_server.login(sender, password)
#      18    smtp_server.sendmail(sender, recipients, msg.as_string())
#      19 print("Message sent!")
#
# File c:\Users\isalo\anaconda3\envs\kota-berbicara\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File c:\Users\isalo\anaconda3\envs\kota-berbicara\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# --> 739     (code, resp) = self.auth(
#     740         authmethod, getattr(self, method_name),
#     741         initial_response_ok=initial_response_ok)
#     742     # 235 == 'Authentication successful'
#     743     # 503 == 'Error: already authenticated'
#     744     if code in (235, 503):
#
# File c:\Users\isalo\anaconda3\envs\kota-berbicara\Lib\smtplib.py:662, in SMTP.auth(self, mechanism, authobject, initial_response_ok)
#     660 if code in (235, 503):
#     661     return (code, resp)
# --> 662 raise SMTPAuthenticationError(code, resp)
#
# SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. For more information, go to\n5.7.8  https://support.google.com/mail/?p=BadCredentials 98e67ed59e1d1-34f5f6db356sm16548064a91.0 - gsmtp')
